# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline used : Display output inline and not in separate window

# %%
plt.plot();

# %%
#also this does same
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4,5]);

# %%
x = [1,2,3,4,5]
y=[23,34,56,7,787]

plt.plot(x,y);

# %%
# from documentation: use object oriented interface instead of plyplot interface

# %%
#1st method
fig =  plt.figure()#creating figure
ax = fig.add_subplot()# add some axex
plt.show()

# %%
#basically did the same as plt.plot()

# %%
#2nd method
fig = plt.figure()
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
#3rd method(recommended)
fig,ax = plt.subplots()
ax.plot(x,y);
